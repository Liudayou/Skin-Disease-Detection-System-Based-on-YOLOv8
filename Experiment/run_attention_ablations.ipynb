# %% [markdown]
# # Attention Ablation Experiments
#
# 本 Notebook 用于逐个运行 ECA, EMA, CBAM 在 P3, P4, P5 层的消融实验。执行时会将每轮（Epoch）的训练信息打印在下方输出框中。

# %% [markdown]
# ### 运行 ECA - P3 实验

# %%
# !python scripts/attention/ablations/train_yolov8m_eca_p3.py
# Out:
# libgomp: Invalid value for environment variable OMP_NUM_THREADS
# New https://pypi.org/project/ultralytics/8.4.46 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32109MiB)
# ...

# %% [markdown]
# ### 运行 ECA - P4 实验

# %%
# !python scripts/attention/ablations/train_yolov8m_eca_p4.py
# Out:
# libgomp: Invalid value for environment variable OMP_NUM_THREADS
# New https://pypi.org/project/ultralytics/8.4.46 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32109MiB)
# ...

# %% [markdown]
# ### 运行 ECA - P5 实验

# %%
# !python scripts/attention/ablations/train_yolov8m_eca_p5.py
# Out:
# libgomp: Invalid value for environment variable OMP_NUM_THREADS
# New https://pypi.org/project/ultralytics/8.4.46 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32109MiB)
# ...

# %% [markdown]
# ### 运行 EMA - P3 实验

# %%
# !python scripts/attention/ablations/train_yolov8m_ema_p3.py
# Out:
# libgomp: Invalid value for environment variable OMP_NUM_THREADS
# New https://pypi.org/project/ultralytics/8.4.46 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32109MiB)
# ...

# %% [markdown]
# ### 运行 EMA - P4 实验

# %%
# !python scripts/attention/ablations/train_yolov8m_ema_p4.py
# Out:
# libgomp: Invalid value for environment variable OMP_NUM_THREADS
# New https://pypi.org/project/ultralytics/8.4.46 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32109MiB)
# ...

# %% [markdown]
# ### 运行 EMA - P5 实验

# %%
# !python scripts/attention/ablations/train_yolov8m_ema_p5.py
# Out:
# libgomp: Invalid value for environment variable OMP_NUM_THREADS
# New https://pypi.org/project/ultralytics/8.4.46 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32109MiB)
# ...

# %% [markdown]
# ### 运行 CBAM - P3 实验

# %%
# !python scripts/attention/ablations/train_yolov8m_cbam_p3.py
# Out:
# libgomp: Invalid value for environment variable OMP_NUM_THREADS
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32109MiB)
# ...

# %% [markdown]
# ### 运行 CBAM  - P4 实验

# %%
# !python scripts/attention/ablations/train_yolov8m_cbam_p4.py
# Out:
# libgomp: Invalid value for environment variable OMP_NUM_THREADS
# New https://pypi.org/project/ultralytics/8.4.46 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32109MiB)
# ...

# %% [markdown]
# ### 运行 CBAM  - P5 实验

# %%
# !python scripts/attention/ablations/train_yolov8m_cbam_p5.py
# Out:
# libgomp: Invalid value for environment variable OMP_NUM_THREADS
# New https://pypi.org/project/ultralytics/8.4.46 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32109MiB)
# ...
